# %%
def initialize_firebase():
    """Initialize Firebase Admin SDK"""
    service_account_path = 'tasksync-70aa9-firebase-adminsdk-fbsvc-cbb97367e1.json'
    
    if not firebase_admin._apps:
        try:
            cred = credentials.Certificate(service_account_path)
            firebase_admin.initialize_app(cred)
            print("✅ Firebase Admin SDK initialized successfully.\n")
            return True
        except FileNotFoundError:
            print(f"❌ Error: Service account key not found at {service_account_path}")
            return False
        except Exception as e:
            print(f"❌ Error initializing Firebase: {e}")
            return False
    return True
# Out:
# ...
# 🤖 DEEP Q-LEARNING TASK SCHEDULER - Firebase Edition with Pattern Analysis
# ...
#
# Step 1️⃣: Initializing Firebase connection...
# ❌ Error: Service account key not found at tasksync-70aa9-firebase-adminsdk-fbsvc-9544c84015.json
# ⚠️ Skipping Firebase - will need valid credentials to proceed.

# %%
# Initialize with correct path
def initialize_firebase_correct():
    """Initialize Firebase Admin SDK with correct service account path"""
    service_account_path = r'C:\Users\ANGEL\Downloads\tasksync03-25-26-main\tasksync03-25-26-main\tasksync-70aa9-firebase-adminsdk-fbsvc-cbb97367e1.json'
    
    if not firebase_admin._apps:
        try:
            cred = credentials.Certificate(service_account_path)
            firebase_admin.initialize_app(cred)
            print("✅ Firebase Admin SDK initialized successfully.\n")
            return True
        except FileNotFoundError:
            print(f"❌ Error: Service account key not found at {service_account_path}")
            return False
        except Exception as e:
            print(f"❌ Error initializing Firebase: {e}")
            import traceback
            traceback.print_exc()
            return False
    return True
# Out:
# ...
# 🧪 TESTING NEARLY-DUE TASK NOTIFICATIONS
# ...
# This test checks Firestore for tasks due within 24 hours...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1000/312554804.py in <cell line: 0>()
#     117 print()
#     118
# --> 119 if initialize_firebase_correct():
#     120     result = check_nearly_due_tasks_local()
#     121     if result > 0:
#
# /tmp/ipykernel_1000/312554804.py in initialize_firebase_correct()
#      94     service_account_path = r'C:\Users\ANGEL\Downloads\tasksync03-25-26-main\tasksync03-25-26-main\tasksync-70aa9-firebase-adminsdk-fbsvc-9544c84015.json'
#      95
# ---> 96     if not firebase_admin._apps:
#      97         try:
#      98             cred = credentials.Certificate(service_account_path)
#
# NameError: name 'firebase_admin' is not defined
